# %%
from prepare_dataset.sr_image_ds_manager import ImageDSManage
from cnn_super_resolution.experiment1 import Model2
from model_saver_manager import model_saver
import inspect

# %%
img_manager = ImageDSManage(["/media/sreramk/storage-main/elementary_frame/dataset/DIV2K_train_HR/"],
                                image_buffer_limit=50, buffer_priority=50)

# %%
model2 = Model2()

input_data, expected_output_data = model2.create_place_holders()

filters, bisases = model2.create_parameters()

parameters = list(filters)
parameters.extend(bisases)

modelsave = model_saver.ModelSaver('exp1_',parameters,
                    save_file_path="/media/sreramk/storage-main/elementary_frame/model_checkpoints")

# %%
dir(modelsave)
# Out:
# ['CHECK_POINT_STORE',
#  'CLOSED',
#  'DATE_HANDLE_FOR_JSON',
#  'DEFAULT_CHECKPOINT',
#  'DEFAULT_EXTENSION',
#  'DYNAMIC_CHECKPOINT',
#  'FIRST_CHECKPOINT',
#  'H_CHECK_POINT_EFFICIENCY',
#  'H_CHECK_POINT_ID',
#  'H_CHECK_POINT_NAME',
#  'H_CHECK_POINT_STORE',
#  'H_CHECK_POINT_TIME_STAMP',
#  'H_FREE_CHECK_POINT_ID',
#  'H_LATEST_CHECK_POINT_ID',
#  'H_NUM_OF_CHECK_POINT',
#  'INDEX_FILE_POSTFIX',
#  'IN_GET_METHOD',
#  'LAST_CHECKPOINT',
#  'LATEST_CHECK_POINT_ID',
#  'MT_PYTORCH',
#  'MT_TENSORFLOW',
#  'NONE_CHECKPOINT',
#  'NOT_IN_GET_METHOD',
#  'OPEN',
#  'STATIC_CHECKPOINT',
#  'TensorFlowParamsHanlde',
#  'TimeIterSkipManager',
#  '_ModelSaver___save_header',
#  '_ModelSaver__add_header_record_to_header',
#  '_ModelSaver__change_h_check_point_store_keys_type',
#  '_ModelSaver__check_if_files_are_corrupt',
#  '_ModelSaver__check_point_digits',
#  '_ModelSaver__checkpoint_num_to_str',
#  '_ModelSaver__checkpoint_record',
#  '_ModelSaver__converter_instance',
#  '_ModelSaver__create_header_structure',
#  '_ModelSaver__create_record_header_structure',
#  '_ModelSaver__create_record_structure',
#  '_ModelSaver__delete_header_record',
#  '_ModelSaver__ensure_exactly_one_field',
#  '_ModelSaver__ensure_first_run',
#  '_ModelSaver__extension',
#  '_ModelSaver__first',
#  '_ModelSaver__first_run',
#  '_ModelSaver__get_checkpoint_addr',
#  '_ModelSaver__get_checkpoint_header',
#  '_ModelSaver__get_checkpoint_index_addr',
#  '_ModelSaver__get_latest_checkpoint_safe',
#  '_ModelSaver__get_new_checkpoint_id',
#  '_ModelSaver__header',
#  '_ModelSaver__header_address',
#  '_ModelSaver__header_initialized',
#  '_ModelSaver__header_not_initialized',
#  '_ModelSaver__last',
#  '_ModelSaver__load_header',
#  '_ModelSaver__new_header',
#  '_ModelSaver__new_record',
#  '_ModelSaver__resolve_checkpoint_id',
#  '_ModelSaver__save_checkpoint_record',
#  '_ModelSaver__save_file_path',
#  '_ModelSaver__save_name',
#  '_ModelSaver__time_iter_skip',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'change_working_tensor_prams',
#  'checkpoint_model',
#  'commit_all',
#  'create_check_point',
#  'delete_all_saved_states',
#  'delete_checkpoint',
#  'get_checkpoint_name',
#  'load_checkpoint',
#  'query_checkpoint_info',
#  'query_get_first_record',
#  'query_get_last_record',
#  'set_first_run',
#  'set_not_first_run']

# %%
inspect.signature(modelsave.query_checkpoint_info)
# Out:
# <Signature (check_point_id_range=None, check_point_time_range=None, check_point_serial_number_range=None, check_point_efficiency_range=None, left_range=1, right_range=1)>

# %%
modelsave.query_checkpoint_info(check_point_time_range=('2018-02-24T00:45:05.455760', '2019-02-24T00:45:12.607582') , left_range=modelsave.OPEN, right_range=modelsave.OPEN)
# Out:
# [OrderedDict([('h_check_point_time_stamp', '2019-02-19T22:58:59.709766'),
#               ('h_check_point_efficiency', None),
#               ('h_check_point_name', 'exp1_00000'),
#               ('h_check_point_ID', 0)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-19T22:59:25.280655'),
#               ('h_check_point_efficiency', None),
#               ('h_check_point_name', 'exp1_00001'),
#               ('h_check_point_ID', 1)]),
#  OrderedDict([('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:05:27.263513'),
#               ('h_check_point_name', 'exp1_00002'),
#               ('h_check_point_ID', 2)]),
#  OrderedDict([('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:06:37.388425'),
#               ('h_check_point_name', 'exp1_00003'),
#               ('h_check_point_ID', 3)]),
#  OrderedDict([('h_check_point_efficiency', None),
#               ('h_check_point_name', 'exp1_00004'),
#               ('h_check_point_time_stamp', '2019-02-19T23:09:03.704684'),
#               ('h_check_point_ID', 4)]),
#  OrderedDict([('h_check_point_efficiency', None),
#               ('h_check_point_name', 'exp1_00005'),
#               ('h_check_point_time_stamp', '2019-02-19T23:09:29.802603'),
#               ('h_check_point_ID', 5)]),
#  OrderedDict([('h_check_point_efficiency', None),
#               ('h_check_point_name', 'exp1_00006'),
#               ('h_check_point_time_stamp', '2019-02-19T23:09:56.480624'),
#               ('h_check_point_ID', 6)]),
#  OrderedDict([('h_check_point_name', 'exp1_00007'),
#               ('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:11:54.740067'),
#               ('h_check_point_ID', 7)]),
#  OrderedDict([('h_check_point_name', 'exp1_00008'),
#               ('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:12:22.317819'),
#               ('h_check_point_ID', 8)]),
#  OrderedDict([('h_check_point_name', 'exp1_00009'),
#               ('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:12:47.844507'),
#               ('h_check_point_ID', 9)]),
#  OrderedDict([('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:15:07.038675'),
#               ('h_check_point_name', 'exp1_00010'),
#               ('h_check_point_ID', 10)]),
#  OrderedDict([('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:22:22.402430'),
#               ('h_check_point_name', 'exp1_00011'),
#               ('h_check_point_ID', 11)]),
#  OrderedDict([('h_check_point_name', 'exp1_00012'),
#               ('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:25:20.143091'),
#               ('h_check_point_ID', 12)]),
#  OrderedDict([('h_check_point_name', 'exp1_00013'),
#               ('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:30:18.040016'),
#               ('h_check_point_ID', 13)]),
#  OrderedDict([('h_check_point_name', 'exp1_00014'),
#               ('h_check_point_efficiency', None),
#               ('h_check_point_time_stamp', '2019-02-19T23:37:56.564002'),
#               ('h_check_point_ID', 14)]),
#  OrderedDict([('h_check_point_name', 'exp1_00015'),
#               ('h_check_point_time_stamp', '2019-02-20T00:11:13.340408'),
#               ('h_check_point_efficiency', 0.0029442477971315384),
#               ('h_check_point_ID', 15)]),
#  OrderedDict([('h_check_point_name', 'exp1_00016'),
#               ('h_check_point_time_stamp', '2019-02-20T00:11:41.166921'),
#               ('h_check_point_efficiency', 0.018452998250722885),
#               ('h_check_point_ID', 16)]),
#  OrderedDict([('h_check_point_name', 'exp1_00017'),
#               ('h_check_point_time_stamp', '2019-02-20T00:12:08.439464'),
#               ('h_check_point_efficiency', 0.00115894281771034),
#               ('h_check_point_ID', 17)]),
#  OrderedDict([('h_check_point_name', 'exp1_00018'),
#               ('h_check_point_efficiency', 0.005900679621845484),
#               ('h_check_point_time_stamp', '2019-02-20T00:13:59.730526'),
#               ('h_check_point_ID', 18)]),
#  OrderedDict([('h_check_point_name', 'exp1_00019'),
#               ('h_check_point_efficiency', 0.0039026541635394096),
#               ('h_check_point_time_stamp', '2019-02-20T00:14:26.647091'),
#               ('h_check_point_ID', 19)]),
#  OrderedDict([('h_check_point_name', 'exp1_00020'),
#               ('h_check_point_efficiency', 0.008505783043801785),
#               ('h_check_point_time_stamp', '2019-02-20T00:14:52.992153'),
#               ('h_check_point_ID', 20)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-20T00:16:56.403906'),
#               ('h_check_point_name', 'exp1_00021'),
#               ('h_check_point_efficiency', 0.0018303990364074707),
#               ('h_check_point_ID', 21)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-20T00:17:23.534474'),
#               ('h_check_point_name', 'exp1_00022'),
#               ('h_check_point_efficiency', 0.005619201343506575),
#               ('h_check_point_ID', 22)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-20T00:17:50.208552'),
#               ('h_check_point_name', 'exp1_00023'),
#               ('h_check_point_efficiency', 0.000874668825417757),
#               ('h_check_point_ID', 23)]),
#  OrderedDict([('h_check_point_name', 'exp1_00024'),
#               ('h_check_point_efficiency', 0.0032379068434238434),
#               ('h_check_point_time_stamp', '2019-02-20T00:19:14.336584'),
#               ('h_check_point_ID', 24)]),
#  OrderedDict([('h_check_point_name', 'exp1_00025'),
#               ('h_check_point_efficiency', 0.003433740697801113),
#               ('h_check_point_time_stamp', '2019-02-20T00:19:41.346921'),
#               ('h_check_point_ID', 25)]),
#  OrderedDict([('h_check_point_name', 'exp1_00026'),
#               ('h_check_point_efficiency', 0.009760711342096329),
#               ('h_check_point_time_stamp', '2019-02-20T00:20:08.629116'),
#               ('h_check_point_ID', 26)]),
#  OrderedDict([('h_check_point_efficiency', 0.010729028843343258),
#               ('h_check_point_name', 'exp1_00027'),
#               ('h_check_point_time_stamp', '2019-02-20T00:21:15.465874'),
#               ('h_check_point_ID', 27)]),
#  OrderedDict([('h_check_point_efficiency', 0.010168098844587803),
#               ('h_check_point_name', 'exp1_00028'),
#               ('h_check_point_time_stamp', '2019-02-20T00:21:42.548907'),
#               ('h_check_point_ID', 28)]),
#  OrderedDict([('h_check_point_efficiency', 0.016337230801582336),
#               ('h_check_point_name', 'exp1_00029'),
#               ('h_check_point_time_stamp', '2019-02-20T00:22:09.439680'),
#               ('h_check_point_ID', 29)]),
#  OrderedDict([('h_check_point_efficiency', 0.004008805844932795),
#               ('h_check_point_time_stamp', '2019-02-20T00:25:58.441353'),
#               ('h_check_point_name', 'exp1_00030'),
#               ('h_check_point_ID', 30)]),
#  OrderedDict([('h_check_point_efficiency', 0.00467353779822588),
#               ('h_check_point_time_stamp', '2019-02-20T00:26:24.707981'),
#               ('h_check_point_name', 'exp1_00031'),
#               ('h_check_point_ID', 31)]),
#  OrderedDict([('h_check_point_efficiency', 0.005293496884405613),
#               ('h_check_point_time_stamp', '2019-02-20T00:26:51.517434'),
#               ('h_check_point_name', 'exp1_00032'),
#               ('h_check_point_ID', 32)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-20T00:30:09.234783'),
#               ('h_check_point_efficiency', 0.0016333904350176454),
#               ('h_check_point_name', 'exp1_00033'),
#               ('h_check_point_ID', 33)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-20T00:30:35.658054'),
#               ('h_check_point_efficiency', 0.004212647210806608),
#               ('h_check_point_name', 'exp1_00034'),
#               ('h_check_point_ID', 34)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-20T00:31:00.671478'),
#               ('h_check_point_efficiency', 0.002482820302248001),
#               ('h_check_point_name', 'exp1_00035'),
#               ('h_check_point_ID', 35)]),
#  OrderedDict([('h_check_point_efficiency', 0.0031167136039584875),
#               ('h_check_point_name', 'exp1_00036'),
#               ('h_check_point_time_stamp', '2019-02-20T00:32:08.606501'),
#               ('h_check_point_ID', 36)]),
#  OrderedDict([('h_check_point_efficiency', 0.00319263176061213),
#               ('h_check_point_name', 'exp1_00037'),
#               ('h_check_point_time_stamp', '2019-02-20T00:32:36.189552'),
#               ('h_check_point_ID', 37)]),
#  OrderedDict([('h_check_point_efficiency', 0.004138032905757427),
#               ('h_check_point_name', 'exp1_00038'),
#               ('h_check_point_time_stamp', '2019-02-20T00:33:02.296866'),
#               ('h_check_point_ID', 38)]),
#  OrderedDict([('h_check_point_name', 'exp1_00039'),
#               ('h_check_point_efficiency', 0.011315674521028996),
#               ('h_check_point_time_stamp', '2019-02-21T14:41:00.113743'),
#               ('h_check_point_ID', 39)]),
#  OrderedDict([('h_check_point_name', 'exp1_00040'),
#               ('h_check_point_efficiency', 0.010376405902206898),
#               ('h_check_point_time_stamp', '2019-02-21T14:41:26.724633'),
#               ('h_check_point_ID', 40)]),
#  OrderedDict([('h_check_point_name', 'exp1_00041'),
#               ('h_check_point_efficiency', 0.004890276584774256),
#               ('h_check_point_time_stamp', '2019-02-21T14:41:53.150005'),
#               ('h_check_point_ID', 41)]),
#  OrderedDict([('h_check_point_name', 'exp1_00042'),
#               ('h_check_point_time_stamp', '2019-02-21T14:43:48.162847'),
#               ('h_check_point_efficiency', 0.00453712185844779),
#               ('h_check_point_ID', 42)]),
#  OrderedDict([('h_check_point_name', 'exp1_00043'),
#               ('h_check_point_time_stamp', '2019-02-21T14:44:14.687525'),
#               ('h_check_point_efficiency', 0.002161875367164612),
#               ('h_check_point_ID', 43)]),
#  OrderedDict([('h_check_point_name', 'exp1_00044'),
#               ('h_check_point_time_stamp', '2019-02-21T14:44:41.304731'),
#               ('h_check_point_efficiency', 0.008198662661015987),
#               ('h_check_point_ID', 44)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T14:45:55.326043'),
#               ('h_check_point_name', 'exp1_00045'),
#               ('h_check_point_efficiency', 0.0052931723184883595),
#               ('h_check_point_ID', 45)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T14:46:23.007183'),
#               ('h_check_point_name', 'exp1_00046'),
#               ('h_check_point_efficiency', 0.003252651309594512),
#               ('h_check_point_ID', 46)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T14:46:49.022863'),
#               ('h_check_point_name', 'exp1_00047'),
#               ('h_check_point_efficiency', 0.008432770147919655),
#               ('h_check_point_ID', 47)]),
#  OrderedDict([('h_check_point_name', 'exp1_00048'),
#               ('h_check_point_efficiency', 0.0032443285454064608),
#               ('h_check_point_time_stamp', '2019-02-21T14:49:13.876173'),
#               ('h_check_point_ID', 48)]),
#  OrderedDict([('h_check_point_name', 'exp1_00049'),
#               ('h_check_point_efficiency', 0.0045364960096776485),
#               ('h_check_point_time_stamp', '2019-02-21T14:49:40.334481'),
#               ('h_check_point_ID', 49)]),
#  OrderedDict([('h_check_point_name', 'exp1_00050'),
#               ('h_check_point_efficiency', 0.013113346882164478),
#               ('h_check_point_time_stamp', '2019-02-21T14:50:06.361743'),
#               ('h_check_point_ID', 50)]),
#  OrderedDict([('h_check_point_efficiency', 0.0018459373386576772),
#               ('h_check_point_name', 'exp1_00051'),
#               ('h_check_point_time_stamp', '2019-02-21T14:53:08.752348'),
#               ('h_check_point_ID', 51)]),
#  OrderedDict([('h_check_point_efficiency', 0.003897432703524828),
#               ('h_check_point_name', 'exp1_00052'),
#               ('h_check_point_time_stamp', '2019-02-21T14:54:28.607021'),
#               ('h_check_point_ID', 52)]),
#  OrderedDict([('h_check_point_efficiency', 0.0018454588716849685),
#               ('h_check_point_name', 'exp1_00053'),
#               ('h_check_point_time_stamp', '2019-02-21T14:55:48.005891'),
#               ('h_check_point_ID', 53)]),
#  OrderedDict([('h_check_point_name', 'exp1_00054'),
#               ('h_check_point_time_stamp', '2019-02-21T14:58:18.303365'),
#               ('h_check_point_efficiency', 0.003165140748023987),
#               ('h_check_point_ID', 54)]),
#  OrderedDict([('h_check_point_name', 'exp1_00055'),
#               ('h_check_point_time_stamp', '2019-02-21T14:59:36.931416'),
#               ('h_check_point_efficiency', 0.0034395779948681593),
#               ('h_check_point_ID', 55)]),
#  OrderedDict([('h_check_point_name', 'exp1_00056'),
#               ('h_check_point_time_stamp', '2019-02-21T15:00:55.332938'),
#               ('h_check_point_efficiency', 0.004475461784750223),
#               ('h_check_point_ID', 56)]),
#  OrderedDict([('h_check_point_name', 'exp1_00057'),
#               ('h_check_point_time_stamp', '2019-02-21T15:02:12.819223'),
#               ('h_check_point_efficiency', 0.003020382486283779),
#               ('h_check_point_ID', 57)]),
#  OrderedDict([('h_check_point_name', 'exp1_00058'),
#               ('h_check_point_time_stamp', '2019-02-21T15:04:31.890131'),
#               ('h_check_point_efficiency', 0.003183231223374605),
#               ('h_check_point_ID', 58)]),
#  OrderedDict([('h_check_point_name', 'exp1_00059'),
#               ('h_check_point_time_stamp', '2019-02-21T15:05:49.702032'),
#               ('h_check_point_efficiency', 0.001591597218066454),
#               ('h_check_point_ID', 59)]),
#  OrderedDict([('h_check_point_name', 'exp1_00060'),
#               ('h_check_point_time_stamp', '2019-02-21T15:07:08.356858'),
#               ('h_check_point_efficiency', 0.005944672040641308),
#               ('h_check_point_ID', 60)]),
#  OrderedDict([('h_check_point_name', 'exp1_00061'),
#               ('h_check_point_time_stamp', '2019-02-21T15:08:26.280535'),
#               ('h_check_point_efficiency', 0.0021283437963575125),
#               ('h_check_point_ID', 61)]),
#  OrderedDict([('h_check_point_name', 'exp1_00062'),
#               ('h_check_point_time_stamp', '2019-02-21T15:11:31.048280'),
#               ('h_check_point_efficiency', 0.004161408636718988),
#               ('h_check_point_ID', 62)]),
#  OrderedDict([('h_check_point_name', 'exp1_00063'),
#               ('h_check_point_time_stamp', '2019-02-21T15:12:49.908605'),
#               ('h_check_point_efficiency', 0.006001302972435951),
#               ('h_check_point_ID', 63)]),
#  OrderedDict([('h_check_point_name', 'exp1_00064'),
#               ('h_check_point_time_stamp', '2019-02-21T15:14:07.964290'),
#               ('h_check_point_efficiency', 0.004819154739379883),
#               ('h_check_point_ID', 64)]),
#  OrderedDict([('h_check_point_name', 'exp1_00065'),
#               ('h_check_point_time_stamp', '2019-02-21T15:15:25.963336'),
#               ('h_check_point_efficiency', 0.0032561917323619127),
#               ('h_check_point_ID', 65)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T16:05:55.316215'),
#               ('h_check_point_efficiency', 0.0022440776228904724),
#               ('h_check_point_name', 'exp1_00066'),
#               ('h_check_point_ID', 66)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T16:07:13.984402'),
#               ('h_check_point_efficiency', 0.0026686829514801502),
#               ('h_check_point_name', 'exp1_00067'),
#               ('h_check_point_ID', 67)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T16:08:32.396041'),
#               ('h_check_point_efficiency', 0.00166134734172374),
#               ('h_check_point_name', 'exp1_00068'),
#               ('h_check_point_ID', 68)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T16:09:51.765633'),
#               ('h_check_point_efficiency', 0.0025479327887296677),
#               ('h_check_point_name', 'exp1_00069'),
#               ('h_check_point_ID', 69)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T16:38:31.792152'),
#               ('h_check_point_efficiency', -18.13469696044922),
#               ('h_check_point_name', 'exp1_00070'),
#               ('h_check_point_ID', 70)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T16:39:50.191953'),
#               ('h_check_point_efficiency', -61.847679138183594),
#               ('h_check_point_name', 'exp1_00071'),
#               ('h_check_point_ID', 71)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T16:41:09.418835'),
#               ('h_check_point_efficiency', -126.2263412475586),
#               ('h_check_point_name', 'exp1_00072'),
#               ('h_check_point_ID', 72)]),
#  OrderedDict([('h_check_point_time_stamp', '2019-02-21T16:42:27.330689'),
#               ('h_check_point_efficiency', -210.16741943359375),
#               ('h_check_point_name', 'exp1_00073'),
#               ('h_check_point_ID', 73)]),
#  OrderedDict([('h_check_point_name', 'exp1_00074'),
#               ('h_check_point_efficiency', 0.00383854191750288),
#               ('h_check_point_time_stamp', '2019-02-21T17:05:39.141468'),
#               ('h_check_point_ID', 74)]),
#  OrderedDict([('h_check_point_name', 'exp1_00075'),
#               ('h_check_point_efficiency', 0.0006593225989490747),
#               ('h_check_point_time_stamp', '2019-02-21T17:06:57.149834'),
#               ('h_check_point_ID', 75)]),
#  OrderedDict([('h_check_point_name', 'exp1_00076'),
#               ('h_check_point_efficiency', 0.005175839178264141),
#               ('h_check_point_time_stamp', '2019-02-21T17:08:14.868517'),
#               ('h_check_point_ID', 76)]),
#  OrderedDict([('h_check_point_name', 'exp1_00077'),
#               ('h_check_point_efficiency', 0.0034028172958642244),
#               ('h_check_point_time_stamp', '2019-02-21T17:09:32.868833'),
#               ('h_check_point_ID', 77)]),
#  OrderedDict([('h_check_point_name', 'exp1_00078'),
#               ('h_check_point_time_stamp', '2019-02-24T00:30:32.191416'),
#               ('h_check_point_efficiency', 0.002468397840857506),
#               ('h_check_point_ID', 78)]),
#  OrderedDict([('h_check_point_name', 'exp1_00079'),
#               ('h_check_point_time_stamp', '2019-02-24T00:31:55.471168'),
#               ('h_check_point_efficiency', 0.004076206590980291),
#               ('h_check_point_ID', 79)]),
#  OrderedDict([('h_check_point_name', 'exp1_00080'),
#               ('h_check_point_time_stamp', '2019-02-24T00:33:16.863162'),
#               ('h_check_point_efficiency', 0.008349076844751835),
#               ('h_check_point_ID', 80)])]

# %%
cod= inspect.getsource(modelsave.query_checkpoint_info)
print(cod)
# Out:
#     def query_checkpoint_info(self, check_point_id_range=None,
#                               check_point_time_range=None,
#                               check_point_serial_number_range=None,
#                               check_point_efficiency_range=None,
#                               left_range=CLOSED,
#                               right_range=CLOSED
#                               ):
#         """
#         Out of the given parameters, only one of the parameters must be a valid range, or this method will throw an
#         exception.
#         :param right_range:
#         :param left_range:
#         :param check_point_id_range:
#         :param check_point_time_range:
#         :param check_point_serial_number_range: if the records are r1, r4, r7, r8, r9, r10, as an example, with the
#                                                 value representing the ID, the position in the listing represents the
#                                                 serial number. That is, it is just the record count range, starting from
#                                                 the beginning.
#         :param check_point_efficiency_range:
#         :return: the record details which can be used to load the data.
#         """
#         field_name = self.__ensure_exactly_one_field(check_point_id_range=check_point_id_range,
#                                                      check_point_time_range=check_point_time_range,
#                                                      check_point_serial_number_range=check_point_serial_number_range,
#                                                      check_point_efficiency_range=check_point_efficiency_range)
#         result = []
#         checkpoint_store = self.__header[ModelSaver.H_CHECK_POINT_STORE]
#
#         def compute_beg_end(checkpoint_range):
#             beg = checkpoint_range[0]
#             end = checkpoint_range[1]
#
#             if left_range == ModelSaver.CLOSED and right_range == ModelSaver.CLOSED:
#                 def compare_indx(beg, val, end):
#                     return beg <= val <= end
#             elif left_range == ModelSaver.CLOSED and right_range == ModelSaver.OPEN:
#                 def compare_indx(beg, val, end):
#                     return beg <= val < end
#             elif left_range == ModelSaver.OPEN and right_range == ModelSaver.CLOSED:
#                 def compare_indx(beg, val, end):
#                     return beg < val <= end
#             elif left_range == ModelSaver.OPEN and right_range == ModelSaver.OPEN:
#                 def compare_indx(beg, val, end):
#                     return beg < val < end
#             else:
#                 raise InvalidLeftRightArgumentCombination
#
#             return beg, end, compare_indx
#
#         def save_to_result(checkpoint_id):
#             temp = copy.deepcopy(checkpoint_store[checkpoint_id])
#             temp[ModelSaver.H_CHECK_POINT_ID] = checkpoint_id
#             result.append(temp)
#
#         def range_match_store(checkpoint_range, key=None):
#             store_iterator = iter(checkpoint_store)
#             beg, end, compare_indx = compute_beg_end(checkpoint_range)
#
#             if key is None:
#                 def default_key(val):
#                     return val
#
#                 key = default_key
#
#             while True:
#                 try:
#                     rec_id = next(store_iterator)
#                 except StopIteration:
#                     break
#
#                 value = key(rec_id)  # checkpoint_store[rec_id][ModelSaver.H_CHECK_POINT_EFFICIENCY]
#                 if value > end:
#                     break
#
#                 if compare_indx(beg, value, end):
#                     save_to_result(rec_id)
#
#         if field_name == 'check_point_id_range':
#             # Note that the key is the ID, in the header for each record, stored in the header file under the
#             # category ModelSaver.H_CHECK_POINT_STORE
#             range_match_store(check_point_id_range)
#             return result
#
#         elif field_name == 'check_point_time_range':
#
#             def time_key(cur_id):
#                 return checkpoint_store[cur_id][ModelSaver.H_CHECK_POINT_TIME_STAMP]
#
#             range_match_store(check_point_time_range, key=time_key)
#             return result
#
#         elif field_name == 'check_point_serial_number_range':
#             beg, end, compare = compute_beg_end(check_point_serial_number_range)
#
#             items_list = checkpoint_store.items()
#             i = beg
#
#             while i < end:
#
#                 if compare(beg, i, end):
#                     save_to_result(items_list[i][0])
#                 elif i > end:
#                     break
#
#                 i += 1
#
#             return result
#
#         elif field_name == 'check_point_efficiency_range':
#
#             def efficiency_key(cur_id):
#                 return checkpoint_store[cur_id][ModelSaver.H_CHECK_POINT_EFFICIENCY]
#
#             range_match_store(check_point_efficiency_range, key=efficiency_key)
#
#             result.sort(key=efficiency_key)
#
#             return result

# %%
modelsave.load_checkpoint(checkpoint_id=70, load_tensors=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d9dd6b79de41> in <module>
# ----> 1 modelsave.load_checkpoint(checkpoint_id=87)
#
# /media/sreramk/storage-main/elementary_frame/model_saver_manager/model_saver.py in load_checkpoint(self, checkpoint_id, load_tensors, commit, reset, **args)
#     436                 self.__header[ModelSaver.H_LATEST_CHECK_POINT_ID] = checkpoint_id
#     437                 if load_tensors:
# --> 438                     self.__converter_instance.set_tensors(pyprams, **args)
#     439                 if commit:
#     440                     self.___save_header()
#
# TypeError: set_tensors() missing 1 required positional argument: 'sess'
